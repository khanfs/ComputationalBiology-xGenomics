# %% [markdown]
# <a href="https://colab.research.google.com/github/khanfs/ComputationalBiology-xGenomics/blob/main/EPMC_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Europe PMC

# %%
from lxml import etree
import requests

# %%
AFF = "Nuffield Population Health"
result_type = 'core'
query_url = 'https://www.ebi.ac.uk/europepmc/webservices/rest/search?query=AFF:“Nuffield Department of Population Health'
response = requests.get(query_url)

# %%
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><responseWrapper xmlns:slx="http://www.scholix.org" xmlns:epmc="https://www.europepmc.org/data"><version>6.8</version><hitCount>17079</hitCount><nextCursorMark>AoIIQGBi9ig0NzU4NjAxMQ==</nextCursorMark><nextPageUrl>https://www.ebi.ac.uk/europepmc/webservices/rest/search?query=AFF:“Nuffield Department of Population Health&amp;cursorMark=AoIIQGBi9ig0NzU4NjAxMQ==&amp;resultType=lite&amp;format=xml</nextPageUrl><request><queryString>AFF:“Nuffield Department of Population Health</queryString><resultType>lite</resultType><cursorMark>*</cursorMark><pageSize>25</pageSize><sort></sort><synonym>false</synonym></request><resultList><result><id>36736537</id><source>MED</source><pmid>36736537</pmid><doi>10.1016/j.kint.2022.12.027</doi><title>Interference of urinary albumin-to-creatinine ratio measurement by glycosuria: clinical implications when using SGLT-2 inhibitors.</title><authorString>Chapman D, Judge PK, Sardell RJ, Staplin N, Arnold T,
# ...
